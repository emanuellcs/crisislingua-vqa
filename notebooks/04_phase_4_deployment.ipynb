# %% [markdown]
# # Phase 4: Final Deployment
# **CrisisLingua-VQA Pipeline**
#
# This final notebook exports the fully validated, memory-safe `JSONL` artifact, preparing it for downstream Vision-Language Model (VLM) training or direct dataset publication.

# %% [markdown]
# ## Setup & Environment

# %%
import sys
from pathlib import Path
from dotenv import load_dotenv

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))
load_dotenv(PROJECT_ROOT / '.env')

# %% [markdown]
# ## Execute Phase 4

# %%
from main import run_phase_4

print("Initiating Phase 4: Deployment...")

# This will generate crisislingua_vqa_final.jsonl in the designated output directory
run_phase_4()

final_artifact = PROJECT_ROOT / 'data' / 'processed' / 'crisislingua_vqa_final.jsonl'

if final_artifact.exists():
    print(f"\nPipeline fully executed!")
    print(f"Your dataset is ready at: {final_artifact}")
else:
    print("\nERROR: Final artifact not found. Please ensure Phase 3 completed successfully.")
