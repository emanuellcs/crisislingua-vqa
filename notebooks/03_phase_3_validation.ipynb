# %% [markdown]
# # Phase 3: Ethical Validation
# **CrisisLingua-VQA Pipeline**
#
# This notebook enforces strict safety and diversity protocols. It executes regular expression (regex) sweeps to strip Personally Identifiable Information (PII) and audits the dataset to ensure under-resourced languages meet statistical distribution thresholds.

# %% [markdown]
# ## Setup & Environment

# %%
import sys
from pathlib import Path
from dotenv import load_dotenv

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))
load_dotenv(PROJECT_ROOT / '.env')

# %% [markdown]
# ## Execute Phase 3

# %%
from main import run_phase_3

print("Initiating Phase 3: Ethical Validation...")
is_compliant = run_phase_3()

if is_compliant:
    print("\nValidation Passed! PII is scrubbed and language thresholds are met.")
    print("You may proceed to Notebook 4 for final deployment.")
else:
    print("\nValidation Failed. Review the logs above to identify which language fell below the threshold or what PII anomalies were detected.")
